# %% [markdown]
# <a href="https://colab.research.google.com/github/abasaltr/projectdemo/blob/main/colab_readcsv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/abasaltr/projectdemo/main/Resources/comic_books.csv")
df
# Out:
#                                               Title  \
# 0                                          10 dance
# 1                        100 Bullets : Brother Lono
# 2        100 Bullets : the deluxe edition book five
# 3                                       100 bullets
# 4                                         1000 cuts
# ...                                             ...
# 15554                                         Zorro
# 15555                                        artist
# 15556                                       iZombie
# 15557              one hundred and forty characters
# 15558  the aggressive adventures of Fearless Griggs
#
#                                             Other titles  \
# 0                                              Ten dance
# 1                                           Brother Lono
# 2                                    One hundred bullets
# 3      Counterfifth detective ; Decayed ; Dirty ; Fir...
# ...
